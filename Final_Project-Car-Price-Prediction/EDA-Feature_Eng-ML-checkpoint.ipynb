# %% [markdown]
# ## About Dataset
#
# ### Scraped data of used cars listings. 100,000 listings, which have been separated into files corresponding to each car manufacturer (total 13 csv files).
#
# ### The data set contains information of price, transmission, mileage, fuel type, road tax, miles per gallon (mpg), and engine size (in liters).

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.exceptions import ConvergenceWarning
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score,GridSearchCV

warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=ConvergenceWarning)


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ## Read the Datasets

# %%
df_audi = pd.read_csv(r"C:\Users\Berat Arslan\PycharmProjects\pythonProject1\DSMLBC8\donem_odevı\datasets\audi.csv")
df_bmw = pd.read_csv(r"C:\Users\Berat Arslan\PycharmProjects\pythonProject1\DSMLBC8\donem_odevı\datasets\bmw.csv")
df_ford = pd.read_csv(r"C:\Users\Berat Arslan\PycharmProjects\pythonProject1\DSMLBC8\donem_odevı\datasets\ford.csv")
df_hyundai = pd.read_csv(r"C:\Users\Berat Arslan\PycharmProjects\pythonProject1\DSMLBC8\donem_odevı\datasets\hyundi.csv")
df_mercedes = pd.read_csv(r"C:\Users\Berat Arslan\PycharmProjects\pythonProject1\DSMLBC8\donem_odevı\datasets\merc.csv")  
df_skoda = pd.read_csv(r"C:\Users\Berat Arslan\PycharmProjects\pythonProject1\DSMLBC8\donem_odevı\datasets\skoda.csv")
df_toyota = pd.read_csv(r"C:\Users\Berat Arslan\PycharmProjects\pythonProject1\DSMLBC8\donem_odevı\datasets\toyota.csv")
df_vauxhall = pd.read_csv(r"C:\Users\Berat Arslan\PycharmProjects\pythonProject1\DSMLBC8\donem_odevı\datasets\vauxhall.csv")
df_vw = pd.read_csv(r"C:\Users\Berat Arslan\PycharmProjects\pythonProject1\DSMLBC8\donem_odevı\datasets\vw.csv")

# %% [markdown]
# ### In Hyundai's dataset, the tax feature was given a different name. So we changed that.

# %%
df_hyundai['tax'] = 'A'
df_hyundai['tax'] = df_hyundai['tax(£)']
df_hyundai.head()
del df_hyundai['tax(£)']

# %%
df_hyundai.head()
# Out:
#      model  year  price transmission  mileage fuelType    mpg  engineSize  tax
# 0      I20  2017   7999       Manual    17307   Petrol 58.900       1.200  145
# 1   Tucson  2016  14499    Automatic    25233   Diesel 43.500       2.000  235
# 2   Tucson  2016  11399       Manual    37877   Diesel 61.700       1.700   30
# 3      I10  2016   6499       Manual    23789   Petrol 60.100       1.000   20
# 4     IX35  2015  10199       Manual    33177   Diesel 51.400       2.000  160

# %% [markdown]
# ## Extraction of The 'brand' Feature

# %%
df_audi['brand'] = 'audi' 
df_bmw['brand'] = 'bmw'
df_ford['brand'] = 'ford'
df_hyundai['brand'] = 'hyundai'
df_mercedes['brand'] = 'mercedes'
df_skoda['brand'] = 'skoda'
df_toyota['brand'] = 'toyota'
df_vauxhall['brand'] = 'vauxhall'
df_vw['brand'] = 'vw'

# %% [markdown]
# ## Combine All to One csv File

# %%
frames = [df_audi, df_bmw, df_ford, df_hyundai, df_mercedes, df_skoda, df_toyota, df_vauxhall, df_vw]
df = pd.concat(frames)
df = df.reset_index(drop=True)
df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax    mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150 55.400       1.400
# 1    A6  2016  16500    Automatic    36203   Diesel   20 64.200       2.000
# 2    A1  2016  11000       Manual    29946   Petrol   30 55.400       1.400
# 3    A4  2017  16800    Automatic    25952   Diesel  145 67.300       2.000
# 4    A3  2019  17300       Manual     1998   Petrol  145 49.600       1.000
#
#   brand
# 0  audi
# 1  audi
# 2  audi
# 3  audi
# 4  audi

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# brand           0
# dtype: int64

# %% [markdown]
# ## Converting 'year' to 'age'

# %%
df['year'] = 2021 - df['year']
df['age'] = df['year']
del df['year']
df.head()
# Out:
#   model  price transmission  mileage fuelType  tax    mpg  engineSize brand  \
# 0    A1  12500       Manual    15735   Petrol  150 55.400       1.400  audi
# 1    A6  16500    Automatic    36203   Diesel   20 64.200       2.000  audi
# 2    A1  11000       Manual    29946   Petrol   30 55.400       1.400  audi
# 3    A4  16800    Automatic    25952   Diesel  145 67.300       2.000  audi
# 4    A3  17300       Manual     1998   Petrol  145 49.600       1.000  audi
#
#    age
# 0    4
# 1    5
# 2    5
# 3    4
# 4    2

# %% [markdown]
# ### When we draw the 'engineSize' and 'fuel consumption(mpg)' graphs, we observe that it is incompatible with real life values. That's why we're deleting the 'fuel consumption(mpg)' variable.

# %% [markdown]
# ![indir.png](attachment:indir.png)

# %%
del df['mpg']

# %%
df.head()
# Out:
#   model  price transmission  mileage fuelType  tax  engineSize brand  age
# 0    A1  12500       Manual    15735   Petrol  150       1.400  audi    4
# 1    A6  16500    Automatic    36203   Diesel   20       2.000  audi    5
# 2    A1  11000       Manual    29946   Petrol   30       1.400  audi    5
# 3    A4  16800    Automatic    25952   Diesel  145       2.000  audi    4
# 4    A3  17300       Manual     1998   Petrol  145       1.000  audi    2

# %%
df.describe([0.01,0.05,0.95,0.99]).T
# Out:
#                count      mean       std     min       1%       5%       50%  \
# price      99187.000 16805.348  9866.773 450.000 3995.000 6495.000 14495.000
# mileage    99187.000 23058.914 21148.524   1.000   10.000 1000.000 17460.000
# tax        99187.000   120.300    63.151   0.000    0.000    0.000   145.000
# engineSize 99187.000     1.663     0.558   0.000    1.000    1.000     1.600
# age        99187.000     3.912     2.124 -39.000    1.000    2.000     4.000
#
#                  95%       99%        max
# price      34400.000 52000.000 159999.000
# mileage    64763.700 96215.380 323000.000
# tax          200.000   265.000    580.000
# engineSize     3.000     3.000      6.600
# age            8.000    11.000     51.000

# %%
df = df[df['engineSize']>0]
df = df[df['age']>0]

# %% [markdown]
# ## Outliers

# %%
def outlier_thresholds(dataframe, col_name, q1=0.02, q3=0.98):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False
    
def grab_col_names(dataframe, cat_th=10, car_th=20):
    """

    Veri setindeki kategorik, numerik ve kategorik fakat kardinal değişkenlerin isimlerini verir.
    Not: Kategorik değişkenlerin içerisine numerik görünümlü kategorik değişkenler de dahildir.

    Parameters
    ------
        dataframe: dataframe
                Değişken isimleri alınmak istenilen dataframe
        cat_th: int, optional
                numerik fakat kategorik olan değişkenler için sınıf eşik değeri
        car_th: int, optinal
                kategorik fakat kardinal değişkenler için sınıf eşik değeri

    Returns
    ------
        cat_cols: list
                Kategorik değişken listesi
        num_cols: list
                Numerik değişken listesi
        cat_but_car: list
                Kategorik görünümlü kardinal değişken listesi

    Examples
    ------
        import seaborn as sns
        df = sns.load_dataset("iris")
        print(grab_col_names(df))


    Notes
    ------
        cat_cols + num_cols + cat_but_car = toplam değişken sayısı
        num_but_cat cat_cols'un içerisinde.
        Return olan 3 liste toplamı toplam değişken sayısına eşittir: cat_cols + num_cols + cat_but_car = değişken sayısı

    """

    # cat_cols, cat_but_car
    cat_cols = [col for col in dataframe.columns if dataframe[col].dtypes == "O"]
    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and
                   dataframe[col].dtypes != "O"]
    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and
                   dataframe[col].dtypes == "O"]
    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    # num_cols
    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O"]
    num_cols = [col for col in num_cols if col not in num_but_cat]

    print(f"Observations: {dataframe.shape[0]}")
    print(f"Variables: {dataframe.shape[1]}")
    print(f'cat_cols: {len(cat_cols)}')
    print(f'num_cols: {len(num_cols)}')
    print(f'cat_but_car: {len(cat_but_car)}')
    print(f'num_but_cat: {len(num_but_cat)}')
    return cat_cols, num_cols, cat_but_car

cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 98913
# Variables: 9
# cat_cols: 3
# num_cols: 5
# cat_but_car: 1
# num_but_cat: 0

# %%
for col in num_cols:
    print(col, check_outlier(df, col))
# Out:
# price True
# mileage True
# tax False
# engineSize True
# age True

# %%
def replace_with_thresholds(dataframe, variable):
    low_limit, up_limit = outlier_thresholds(dataframe, variable)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

# %%
for col in num_cols:
    replace_with_thresholds(df, col)

# %%
df.describe().T
# Out:
#                count      mean       std     min      25%       50%       75%  \
# price      98913.000 16795.723  9770.469 450.000 9999.000 14495.000 20875.000
# mileage    98913.000 23059.990 21108.949   1.000 7424.000 17456.000 32346.000
# tax        98913.000   120.322    63.121   0.000  125.000   145.000   145.000
# engineSize 98913.000     1.668     0.551   0.600    1.200     1.600     2.000
# age        98913.000     3.912     2.106   1.000    2.000     4.000     5.000
#
#                   max
# price      104977.500
# mileage    207453.500
# tax           580.000
# engineSize      6.000
# age            21.000

# %% [markdown]
# ## Feature Extraction (Adding 2 New Features consisting of 9 Categories )

# %%
df.loc[(df['mileage']<7500)&(df['age']<3),'mileage_age'] = 'm1a1'

df.loc[(df['mileage']<7500)&(df['age']>=3)&(df['age']<=5),'mileage_age'] = 'm1a2'

df.loc[(df['mileage']<7500)&(df['age']>5),'mileage_age'] = 'm1a3'

# %%
df.loc[(df['mileage']>=7500)&(df['mileage']<32500)&(df['age']<3),'mileage_age'] = 'm2a1'

df.loc[(df['mileage']>=7500)&(df['mileage']<32500)&(df['age']>=3)&(df['age']<6),'mileage_age'] = 'm2a2'

df.loc[(df['mileage']>=7500)&(df['mileage']<32500)&(df['age']>5),'mileage_age'] = 'm2a3'

# %%
df.loc[(df['mileage']>=32500)&(df['age']<3),'mileage_age'] = 'm3a1'

df.loc[(df['mileage']>=32500)&(df['age']>=3)&(df['age']<=5),'mileage_age'] = 'm3a2'

df.loc[(df['mileage']>=32500)&(df['age']>5),'mileage_age'] = 'm3a3'

# %%
df['mileage_age'].unique()
# Out:
# array(['m2a2', 'm3a2', 'm1a1', 'm3a3', 'm2a3', 'm2a1', 'm1a2', 'm1a3',
#        'm3a1'], dtype=object)

# %%
df.loc[(df['engineSize']<1300)&(df['age']<3),'eS_age'] = 'e1a1'

df.loc[(df['engineSize']<1300)&(df['age']>=3)&(df['age']<=5),'eS_age'] = 'e1a2'

df.loc[(df['engineSize']<1300)&(df['age']>5),'eS_age'] = 'e1a3'

# %%
df.loc[(df['engineSize']>=1300)&(df['engineSize']<2000)&(df['age']<3),'eS_age'] = 'e2a1'

df.loc[(df['engineSize']>=1300)&(df['engineSize']<2000)&(df['age']>=3)&(df['age']<6),'eS_age'] = 'e2a2'

df.loc[(df['engineSize']>=1300)&(df['engineSize']<2000)&(df['age']>5),'eS_age'] = 'e2a3'

# %%
df.loc[(df['engineSize']>=2000)&(df['age']<3),'eS_age'] = 'e3a1'

df.loc[(df['engineSize']>=2000)&(df['age']>=3)&(df['age']<=5),'eS_age'] = 'e3a2'

df.loc[(df['engineSize']>=2000)&(df['age']>5),'eS_age'] = 'e3a3'

# %%
df.head()
# Out:
#   model     price transmission   mileage fuelType     tax  engineSize brand  \
# 0    A1 12500.000       Manual 15735.000   Petrol 150.000       1.400  audi
# 1    A6 16500.000    Automatic 36203.000   Diesel  20.000       2.000  audi
# 2    A1 11000.000       Manual 29946.000   Petrol  30.000       1.400  audi
# 3    A4 16800.000    Automatic 25952.000   Diesel 145.000       2.000  audi
# 4    A3 17300.000       Manual  1998.000   Petrol 145.000       1.000  audi
#
#    age mileage_age eS_age
# 0    4        m2a2   e1a2
# 1    5        m3a2   e1a2
# 2    5        m2a2   e1a2
# 3    4        m2a2   e1a2
# 4    2        m1a1   e1a1

# %%
df.isnull().any()
# Out:
# model           False
# price           False
# transmission    False
# mileage         False
# fuelType        False
# tax             False
# engineSize      False
# brand           False
# age             False
# mileage_age     False
# eS_age          False
# dtype: bool

# %% [markdown]
# ## Label Encoding & One-Hot Encoding

# %%
cat_cols, cat_but_car, num_cols = grab_col_names(df)
# Out:
# Observations: 98913
# Variables: 11
# cat_cols: 5
# num_cols: 5
# cat_but_car: 1
# num_but_cat: 0

# %%
cat_cols.append('model')
cat_cols
# Out:
# ['transmission', 'fuelType', 'brand', 'mileage_age', 'eS_age', 'model']

# %%
num_cols = ['price','engineSize','age','mileage','tax']

# %%
def label_encoder(dataframe, binary_col):
    labelencoder = LabelEncoder()
    dataframe[binary_col] = labelencoder.fit_transform(dataframe[binary_col])
    return dataframe

# %%
binary_cols = [col for col in df.columns if df[col].dtypes == "O" and len(df[col].unique()) == 2]

# %%
for col in binary_cols:
    label_encoder(df, col)

# %%
def one_hot_encoder(dataframe, categorical_cols, drop_first=False):
    dataframe = pd.get_dummies(dataframe, columns=categorical_cols, drop_first=drop_first)
    return dataframe

df = one_hot_encoder(df, cat_cols, drop_first=True)

df.head(1)
# Out:
#       price   mileage     tax  engineSize  age  transmission_Manual  \
# 0 12500.000 15735.000 150.000       1.400    4                    1
#
#    transmission_Other  transmission_Semi-Auto  fuelType_Electric  \
# 0                   0                       0                  0
#
#    fuelType_Hybrid  fuelType_Other  fuelType_Petrol  brand_bmw  brand_ford  \
# 0                0               0                1          0           0
#
#    brand_hyundai  brand_mercedes  brand_skoda  brand_toyota  brand_vauxhall  \
# 0              0               0            0             0               0
#
#    brand_vw  mileage_age_m1a2  mileage_age_m1a3  mileage_age_m2a1  \
# 0         0                 0                 0                 0
#
#    mileage_age_m2a2  mileage_age_m2a3  mileage_age_m3a1  mileage_age_m3a2  \
# 0                 1                 0                 0                 0
#
#    mileage_age_m3a3  eS_age_e1a2  eS_age_e1a3  model_ 2 Series  \
# 0                 0            1            0                0
#
#    model_ 3 Series  model_ 4 Series  model_ 5 Series  model_ 6 Series  \
# 0                0                0                0                0
#
#    model_ 7 Series  model_ 8 Series  model_ A Class  model_ A1  model_ A2  \
# 0                0                0               0          1          0
#
#    model_ A3  model_ A4  model_ A5  model_ A6  model_ A7  model_ A8  \
# 0          0          0          0          0          0          0
#
#    model_ Accent  model_ Adam  model_ Agila  model_ Amarok  model_ Amica  \
# 0              0            0             0              0             0
#
#    model_ Ampera  model_ Antara  model_ Arteon  model_ Astra  model_ Auris  \
# 0              0              0              0             0             0
#
#    model_ Avensis  model_ Aygo  model_ B Class  model_ B-MAX  model_ Beetle  \
# 0               0            0               0             0              0
#
#    model_ C Class  model_ C-HR  model_ C-MAX  model_ CC  model_ CL Class  \
# 0               0            0             0          0                0
#
#    model_ CLA Class  model_ CLC Class  model_ CLK  model_ CLS Class  \
# 0                 0                 0           0                 0
#
#    model_ Caddy  model_ Caddy Life  model_ Caddy Maxi  model_ Caddy Maxi Life  \
# 0             0                  0                  0                       0
#
#    model_ California  model_ Camry  model_ Caravelle  model_ Cascada  \
# 0                  0             0                 0               0
#
#    model_ Citigo  model_ Combo Life  model_ Corolla  model_ Corsa  \
# 0              0                  0               0             0
#
#    model_ Crossland X  model_ E Class  model_ EcoSport  model_ Edge  \
# 0                   0               0                0            0
#
#    model_ Eos  model_ Escort  model_ Fabia  model_ Fiesta  model_ Focus  \
# 0           0              0             0              0             0
#
#    model_ Fox  model_ Fusion  model_ G Class  model_ GL Class  \
# 0           0              0               0                0
#
#    model_ GLA Class  model_ GLB Class  model_ GLC Class  model_ GLE Class  \
# 0                 0                 0                 0                 0
#
#    model_ GLS Class  model_ GT86  model_ GTC  model_ Galaxy  model_ Getz  \
# 0                 0            0           0              0            0
#
#    model_ Golf  model_ Golf SV  model_ Grand C-MAX  \
# 0            0               0                   0
#
#    model_ Grand Tourneo Connect  model_ Grandland X  model_ Hilux  model_ I10  \
# 0                             0                   0             0           0
#
#    model_ I20  model_ I30  model_ I40  model_ I800  model_ IQ  model_ IX20  \
# 0           0           0           0            0          0            0
#
#    model_ IX35  model_ Insignia  model_ Ioniq  model_ Jetta  model_ KA  \
# 0            0                0             0             0          0
#
#    model_ Ka+  model_ Kadjar  model_ Kamiq  model_ Karoq  model_ Kodiaq  \
# 0           0              0             0             0              0
#
#    model_ Kona  model_ Kuga  model_ Land Cruiser  model_ M Class  model_ M2  \
# 0            0            0                    0               0          0
#
#    model_ M3  model_ M4  model_ M5  model_ M6  model_ Meriva  model_ Mokka  \
# 0          0          0          0          0              0             0
#
#    model_ Mokka X  model_ Mondeo  model_ Mustang  model_ Octavia  \
# 0               0              0               0               0
#
#    model_ PROACE VERSO  model_ Passat  model_ Polo  model_ Prius  model_ Puma  \
# 0                    0              0            0             0            0
#
#    model_ Q2  model_ Q3  model_ Q5  model_ Q7  model_ Q8  model_ R Class  \
# 0          0          0          0          0          0               0
#
#    model_ R8  model_ RAV4  model_ RS3  model_ RS4  model_ RS5  model_ RS6  \
# 0          0            0           0           0           0           0
#
#    model_ RS7  model_ Ranger  model_ Rapid  model_ Roomster  model_ S Class  \
# 0           0              0             0                0               0
#
#    model_ S-MAX  model_ S3  model_ S4  model_ S5  model_ S8  model_ SL CLASS  \
# 0             0          0          0          0          0                0
#
#    model_ SLK  model_ SQ5  model_ SQ7  model_ Santa Fe  model_ Scala  \
# 0           0           0           0                0             0
#
#    model_ Scirocco  model_ Sharan  model_ Shuttle  model_ Streetka  \
# 0                0              0               0                0
#
#    model_ Superb  model_ Supra  model_ T-Cross  model_ T-Roc  model_ TT  \
# 0              0             0               0             0          0
#
#    model_ Terracan  model_ Tigra  model_ Tiguan  model_ Tiguan Allspace  \
# 0                0             0              0                       0
#
#    model_ Touareg  model_ Touran  model_ Tourneo Connect  \
# 0               0              0                       0
#
#    model_ Tourneo Custom  model_ Transit Tourneo  model_ Tucson  model_ Up  \
# 0                      0                       0              0          0
#
#    model_ Urban Cruiser  model_ V Class  model_ Vectra  model_ Veloster  \
# 0                     0               0              0                0
#
#    model_ Verso  model_ Verso-S  model_ Viva  model_ Vivaro  model_ X-CLASS  \
# 0             0               0            0              0               0
#
#    model_ X1  model_ X2  model_ X3  model_ X4  model_ X5  model_ X6  \
# 0          0          0          0          0          0          0
#
#    model_ X7  model_ Yaris  model_ Yeti  model_ Yeti Outdoor  model_ Z3  \
# 0          0             0            0                    0          0
#
#    model_ Z4  model_ Zafira  model_ Zafira Tourer  model_ i3  model_ i8  \
# 0          0              0                     0          0          0
#
#    model_180  model_200  model_220
# 0          0          0          0

# %% [markdown]
# ## Log Transformation

# %%
y = np.log1p(df['price'])
X = df.drop(["price"], axis=1)

# %% [markdown]
# ## Splitting the dataset into 'train' and 'test'

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=17)

# %% [markdown]
# ## Running These Regression Models for The Best RMSE Results

# %%
models = [('LR', LinearRegression()),
          ("Ridge", Ridge()),
          ("Lasso", Lasso()),
          ("ElasticNet", ElasticNet()),
          ('KNN', KNeighborsRegressor()),
          ('CART', DecisionTreeRegressor()),
          ('RF', RandomForestRegressor()),
          #('SVR', SVR()),
          ('GBM', GradientBoostingRegressor()),
          ("XGBoost", XGBRegressor(objective='reg:squarederror')),
          ("LightGBM", LGBMRegressor()),
         ("CatBoost", CatBoostRegressor(verbose=False))]

# %%
for name, regressor in models:
    rmse = np.mean(np.sqrt(-cross_val_score(regressor, X, y, cv=10, scoring="neg_mean_squared_error")))
    print(f"RMSE: {round(rmse, 4)} ({name}) ")
# Out:
# RMSE: 0.1899 (LR)
# RMSE: 0.1901 (Ridge)
# RMSE: 0.4576 (Lasso)
# RMSE: 0.4573 (ElasticNet)
# RMSE: 0.4297 (KNN)
# RMSE: 0.2215 (CART)
# RMSE: 0.1866 (RF)
# RMSE: 0.2138 (GBM)
# RMSE: 0.1736 (XGBoost)
# RMSE: 0.1855 (LightGBM)
# RMSE: 0.1653 (CatBoost)

# %% [markdown]
# ## Modelling

# %%
cat_boost_model = CatBoostRegressor(verbose=False)

# %%
rmse = np.mean(np.sqrt(-cross_val_score(cat_boost_model, X, y, cv=10, scoring="neg_mean_squared_error")))

# %%
rmse
# Out:
# 0.16531946736639985

# %% [markdown]
# ## Hyperparameter Optimization for the Best-Performing 'Catboost Regressor' Model

# %%
parameters = {'depth'         : [7,8,9],
              'learning_rate' : [0.11, 0.12, 0.13],
              'iterations'    : [1600, 1700, 1800]}

# %%
cat_boost_model_best = GridSearchCV(cat_boost_model,parameters,cv=5,n_jobs=-1,verbose=True).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits

# %%
cat_boost_model_best.best_params_
# Out:
# {'depth': 9, 'iterations': 1800, 'learning_rate': 0.13}

# %%
#A =  cat_boost_model_best.best_params_

# %%
#A = {'depth': 9, 'iterations': 1800, 'learning_rate': 0.13}
#A

# %%
final_model = cat_boost_model.set_params(**cat_boost_model_best.best_params_).fit(X, y)

# %%
rmse = np.mean(np.sqrt(-cross_val_score(final_model, X, y, cv=10, scoring="neg_mean_squared_error")))

# %%
rmse
# Out:
# 0.16350533259082684

# %% [markdown]
# ## Final Model

# %%
cat_boost_tuned = CatBoostRegressor(**cat_boost_model_best.best_params_).fit(X_train, y_train)
y_pred = cat_boost_tuned.predict(X_test)
# Out:
# 0:	learn: 0.4784033	total: 9.67ms	remaining: 17.4s
# 1:	learn: 0.4323252	total: 18.9ms	remaining: 17s
# 2:	learn: 0.3918742	total: 27.7ms	remaining: 16.6s
# 3:	learn: 0.3573777	total: 36.3ms	remaining: 16.3s
# 4:	learn: 0.3294684	total: 44.6ms	remaining: 16s
# 5:	learn: 0.3060873	total: 52.8ms	remaining: 15.8s
# 6:	learn: 0.2857302	total: 61.2ms	remaining: 15.7s
# 7:	learn: 0.2688979	total: 69.4ms	remaining: 15.5s
# 8:	learn: 0.2536912	total: 77.9ms	remaining: 15.5s
# 9:	learn: 0.2414138	total: 86ms	remaining: 15.4s
# 10:	learn: 0.2305249	total: 94.5ms	remaining: 15.4s
# 11:	learn: 0.2218419	total: 103ms	remaining: 15.3s
# 12:	learn: 0.2134212	total: 111ms	remaining: 15.3s
# 13:	learn: 0.2069510	total: 119ms	remaining: 15.2s
# 14:	learn: 0.2011072	total: 128ms	remaining: 15.2s
# 15:	learn: 0.1949374	total: 136ms	remaining: 15.2s
# 16:	learn: 0.1904152	total: 144ms	remaining: 15.1s
# 17:	learn: 0.1865576	total: 152ms	remaining: 15.1s
# 18:	learn: 0.1834454	total: 161ms	remaining: 15s
# 19:	learn: 0.1800837	total: 169ms	remaining: 15s
# 20:	learn: 0.1771429	total: 177ms	remaining: 15s
# 21:	learn: 0.1749000	total: 185ms	remaining: 14.9s
# 22:	learn: 0.1727176	total: 193ms	remaining: 14.9s
# 23:	learn: 0.1707573	total: 202ms	remaining: 14.9s
# 1766:	learn: 0.0828424	total: 14.6s	remaining: 273ms
# 1767:	learn: 0.0828351	total: 14.6s	remaining: 265ms
# 1768:	learn: 0.0828350	total: 14.6s	remaining: 256ms
# 1769:	learn: 0.0828300	total: 14.6s	remaining: 248ms
# 1770:	learn: 0.0828281	total: 14.6s	remaining: 240ms
# 1771:	learn: 0.0828227	total: 14.6s	remaining: 231ms
# 1772:	learn: 0.0828159	total: 14.7s	remaining: 223ms
# 1773:	learn: 0.0828107	total: 14.7s	remaining: 215ms
# 1774:	learn: 0.0828035	total: 14.7s	remaining: 207ms
# 1775:	learn: 0.0828000	total: 14.7s	remaining: 198ms
# 1776:	learn: 0.0827868	total: 14.7s	remaining: 190ms
# 1777:	learn: 0.0827830	total: 14.7s	remaining: 182ms
# 1778:	learn: 0.0827778	total: 14.7s	remaining: 174ms
# 1779:	learn: 0.0827705	total: 14.7s	remaining: 165ms
# 1780:	learn: 0.0827595	total: 14.7s	remaining: 157ms
# 1781:	learn: 0.0827569	total: 14.7s	remaining: 149ms
# 1782:	learn: 0.0827502	total: 14.7s	remaining: 141ms
# 1783:	learn: 0.0827452	total: 14.7s	remaining: 132ms
# 1784:	learn: 0.0827366	total: 14.8s	remaining: 124ms
# 1785:	learn: 0.0827316	total: 14.8s	remaining: 116ms
# 1786:	learn: 0.0827291	total: 14.8s	remaining: 107ms
# 1787:	learn: 0.0827251	total: 14.8s	remaining: 99.2ms
# 1788:	learn: 0.0827196	total: 14.8s	remaining: 90.9ms
# 1789:	learn: 0.0827160	total: 14.8s	remaining: 82.7ms
# 1790:	learn: 0.0827070	total: 14.8s	remaining: 74.4ms
# 1791:	learn: 0.0827021	total: 14.8s	remaining: 66.1ms
# 1792:	learn: 0.0826982	total: 14.8s	remaining: 57.9ms
# 1793:	learn: 0.0826923	total: 14.8s	remaining: 49.6ms
# 1794:	learn: 0.0826826	total: 14.8s	remaining: 41.3ms
# 1795:	learn: 0.0826780	total: 14.8s	remaining: 33.1ms
# 1796:	learn: 0.0826730	total: 14.9s	remaining: 24.8ms
# 1797:	learn: 0.0826656	total: 14.9s	remaining: 16.5ms
# 1798:	learn: 0.0826656	total: 14.9s	remaining: 8.27ms
# 1799:	learn: 0.0826626	total: 14.9s	remaining: 0us

# %% [markdown]
# ## Inversing the log Transform

# %%
new_y = np.expm1(y_pred)
new_y_test = np.expm1(y_test)

np.sqrt(mean_squared_error(new_y_test, new_y))
# Out:
# 1979.1822396958178

# %% [markdown]
#  ## Testing The Final Model

# %%
# Train RMSE
y_pred = final_model.predict(X_train)
np.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 0.08386816976279211

# %%
# TRAIN RKARE
final_model.score(X_train, y_train)
# Out:
# 0.9751910691476736

# %%
# Test RMSE
y_pred = final_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 0.08477066463170284

# %%
# Test RKARE
final_model.score(X_test, y_test)
# Out:
# 0.9754910530266766

# %% [markdown]
# ## Prediction for a New Observation

# %%
df.columns
random_user = X.sample(1)
#np.array(10**final_model.predict(random_user))

# %% [markdown]
# ## Saving The Model

# %%
joblib.dump(final_model, "final_model.pkl")
